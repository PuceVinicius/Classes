# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

import warnings; warnings.simplefilter('ignore')

# %%
import pandas as pd

affairs = pd.read_csv('http://vision.ime.usp.br/~hirata/Fair.csv')

# %%
import seaborn as sns
import numpy as np

filename = 'student-por.csv'

data = pd.read_csv('student-por.csv', sep=';')
sns.distplot(data['age'], rug=True, kde=False);

# %%
sns.barplot(data['studytime'])

# %%
for x in range (0, 650):
    if data['failures'][x] > 0:
        data['failedFree'][x] = data['freetime']
    else:
        data['failedFree'][x] = -1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'failedFree'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-802f2b5f034f> in <module>()
# ...

# %%
print(data['freetime'][20])
# Out:
# 4
